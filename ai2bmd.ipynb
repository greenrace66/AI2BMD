# %%
# skip the following two lines if you've already set up the launcher
# !wget 'https://raw.githubusercontent.com/greenrace66/AI2BMD/main/scripts/ai2bmd'
# !chmod +x ai2bmd
# !pip install udocker
# !udocker --allow-root install
# download the Chignolin protein structure data file
# !wget 'https://raw.githubusercontent.com/microsoft/AI2BMD/main/examples/chig.pdb'
# download the preprocessed and solvated Chignolin protein structure data files
# !wget --directory-prefix=chig_preprocessed 'https://raw.githubusercontent.com/microsoft/AI2BMD/main/examples/chig_preprocessed/chig-preeq.pdb'
# !wget --directory-prefix=chig_preprocessed 'https://raw.githubusercontent.com/microsoft/AI2BMD/main/examples/chig_preprocessed/chig-preeq-nowat.pdb'
# pull the docker image from the container registry
# !udocker --allow-root pull ghcr.io/microsoft/ai2bmd:latest
# launch the program, with all simulation parameters set to default values
# you may need to "sudo" the following line if the docker group is not configured for the user
# !./ai2bmd --prot-file chig.pdb --preprocess-dir chig_preprocessed --preeq-steps 10 --temp-k 373 --timestep 4 --sim-steps 1000 --record-per-steps 1
# Out:
# --2024-11-07 10:33:52--  https://raw.githubusercontent.com/greenrace66/AI2BMD/main/scripts/ai2bmd
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14360 (14K) [text/plain]
# Saving to: ‘ai2bmd’
#
# ai2bmd              100%[===================>]  14.02K  --.-KB/s    in 0s
#
# 2024-11-07 10:33:52 (84.0 MB/s) - ‘ai2bmd’ saved [14360/14360]
#
# Collecting udocker
#   Downloading udocker-1.3.17-py2.py3-none-any.whl.metadata (37 kB)
# Downloading udocker-1.3.17-py2.py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.6/119.6 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: udocker
# Successfully installed udocker-1.3.17
# Info: creating repo: /root/.udocker
# Info: udocker command line interface 1.3.17
# Info: searching for udockertools >= 1.2.11
# Info: installing udockertools 1.2.11
# Info: installation of udockertools successful
# --2024-11-07 10:34:01--  https://raw.githubusercontent.com/microsoft/AI2BMD/main/examples/chig.pdb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14281 (14K) [text/plain]
# Saving to: ‘chig.pdb’
#
# chig.pdb            100%[===================>]  13.95K  --.-KB/s    in 0s
#
# 2024-11-07 10:34:01 (116 MB/s) - ‘chig.pdb’ saved [14281/14281]
#
# --2024-11-07 10:34:01--  https://raw.githubusercontent.com/microsoft/AI2BMD/main/examples/chig_preprocessed/chig-preeq.pdb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1448513 (1.4M) [text/plain]
# Saving to: ‘chig_preprocessed/chig-preeq.pdb’
#
# chig-preeq.pdb      100%[===================>]   1.38M  --.-KB/s    in 0.006s
#
# 2024-11-07 10:34:02 (224 MB/s) - ‘chig_preprocessed/chig-preeq.pdb’ saved [1448513/1448513]
#
# --2024-11-07 10:34:02--  https://raw.githubusercontent.com/microsoft/AI2BMD/main/examples/chig_preprocessed/chig-preeq-nowat.pdb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14246 (14K) [text/plain]
# Saving to: ‘chig_preprocessed/chig-preeq-nowat.pdb’
#
# chig-preeq-nowat.pd 100%[===================>]  13.91K  --.-KB/s    in 0s
#
# 2024-11-07 10:34:02 (115 MB/s) - ‘chig_preprocessed/chig-preeq-nowat.pdb’ saved [14246/14246]
#
# Info: downloading layer sha256:739606b649dbdee54104892a99f72937e937896fe8b89343105c8bfe34b3be39
# Info: downloading layer sha256:b818a2599bfca0d7afc9cc9cf4b4751f2ff8a49b7f9882115bc267217b353ad4
# Info: downloading layer sha256:2f6fae2dd0f879a766264caa17adb6bab1044b412f67c9d87d97d38c63bed047
# Info: downloading layer sha256:a66271ff119ce0e4831867d51bf38bfe5f24c15df34c60660c82c3770108a240
# Info: downloading layer sha256:8416a41d74942c4fdbbe1d09454f6de4b606a1f343b284d9f7a5a73e1e79bd6a
# Info: downloading layer sha256:004abbf872abed069e097e8c2dbc8e21f13b2156b0561b50d9c33d3cc0a2de5b
# Info: downloading layer sha256:3eb9659d2d17edd8564ebe11896323f426bd46e6422ed1b94eee52352735555f
